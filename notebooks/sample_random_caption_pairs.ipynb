# %% [markdown]
# # Sample 50 Random Frame-Caption Pairs
#
# This notebook reads `artifacts/datasets/frame_caption_pairs/shard-00000-caption-00000.tar`, matches `.png` frames with `.txt` captions, samples 50 valid pairs, and renders them for inspection.
#
# The notebook is structured to:
# 1. import the required libraries,
# 2. inspect the shard layout,
# 3. extract and match frame-caption entries,
# 4. sample up to 50 random pairs, and
# 5. display the results.

# %%
import io
import random
import tarfile
from pathlib import Path

from PIL import Image
from IPython.display import Markdown, display

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "artifacts").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

SHARD_PATH = PROJECT_ROOT / "artifacts" / "datasets" / "frame_caption_pairs" / "shard-00000-caption-00000.tar"
SAMPLE_COUNT = 50
RANDOM_SEED = 7

if not SHARD_PATH.exists():
    raise FileNotFoundError(f"Shard not found: {SHARD_PATH.resolve()}")

random.seed(RANDOM_SEED)
print(f"Using shard: {SHARD_PATH.resolve()}")
print(f"Requested sample count: {SAMPLE_COUNT}")
print(f"Random seed: {RANDOM_SEED}")
# Out:
# Using shard: /Users/hengwei/Desktop/AGILE-WM/artifacts/datasets/frame_caption_pairs/shard-00000-caption-00000.tar
# Requested sample count: 50
# Random seed: 7

# %%
with tarfile.open(SHARD_PATH, "r") as tar:
    member_names = [member.name for member in tar.getmembers()]

print(f"Total archive members: {len(member_names)}")
print("First 12 entries:")
for name in member_names[:12]:
    print(f"  {name}")

png_count = sum(name.endswith(".png") for name in member_names)
txt_count = sum(name.endswith(".txt") for name in member_names)
json_count = sum(name.endswith(".json") for name in member_names)

print()
print(f"PNG files:  {png_count}")
print(f"TXT files:  {txt_count}")
print(f"JSON files: {json_count}")
# Out:
# Total archive members: 3000
# First 12 entries:
#   episode_000000_frame_000091.png
#   episode_000000_frame_000091.txt
#   episode_000000_frame_000091.json
#   episode_000000_frame_000112.png
#   episode_000000_frame_000112.txt
#   episode_000000_frame_000112.json
#   episode_000000_frame_000113.png
#   episode_000000_frame_000113.txt
#   episode_000000_frame_000113.json
#   episode_000000_frame_000189.png
#   episode_000000_frame_000189.txt
#   episode_000000_frame_000189.json
#
# PNG files:  1000
# TXT files:  1000
# JSON files: 1000

# %%
frame_members = {}
caption_members = {}

for name in member_names:
    path = Path(name)
    if path.suffix == ".png":
        frame_members[path.stem] = name
    elif path.suffix == ".txt":
        caption_members[path.stem] = name

valid_keys = sorted(frame_members.keys() & caption_members.keys())
selected_count = min(SAMPLE_COUNT, len(valid_keys))
selected_keys = random.sample(valid_keys, k=selected_count) if selected_count else []

print(f"Matched frame-caption pairs: {len(valid_keys)}")
print(f"Selected pairs: {len(selected_keys)}")
if len(valid_keys) < SAMPLE_COUNT:
    print("Fewer than 50 valid pairs were available, so all pairs were selected.")

selected_keys[:10]
# Out:
# Matched frame-caption pairs: 1000
# Selected pairs: 50
# ['episode_000016_frame_000520',
#  'episode_000048_frame_000400',
#  'episode_000007_frame_000703',
#  'episode_000020_frame_000293',
#  'episode_000033_frame_000417',
#  'episode_000002_frame_000344',
#  'episode_000003_frame_000738',
#  'episode_000042_frame_000059',
#  'episode_000027_frame_000385',
#  'episode_000004_frame_000792']

# %%
if not selected_keys:
    raise RuntimeError("No valid frame-caption pairs were found in the shard.")

with tarfile.open(SHARD_PATH, "r") as tar:
    for index, sample_key in enumerate(selected_keys, start=1):
        frame_name = frame_members[sample_key]
        caption_name = caption_members[sample_key]

        frame_file = tar.extractfile(frame_name)
        caption_file = tar.extractfile(caption_name)
        if frame_file is None or caption_file is None:
            continue

        image = Image.open(io.BytesIO(frame_file.read())).convert("RGB")
        caption = caption_file.read().decode("utf-8").strip()

        display(Markdown(f"## Pair {index}: `{sample_key}`"))
        display(image)
        display(Markdown("**Caption**"))
        display(Markdown(f"```text\n{caption}\n```"))
# Out:
# ## Pair 1: `episode_000016_frame_000520`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=right, surface=asphalt, heading alignment=slightly right, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 2: `episode_000048_frame_000400`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=right, surface=asphalt, heading alignment=slightly right, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 3: `episode_000007_frame_000703`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=center, surface=asphalt, heading alignment=slightly left, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 4: `episode_000020_frame_000293`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 5: `episode_000033_frame_000417`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 6: `episode_000002_frame_000344`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 7: `episode_000003_frame_000738`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 8: `episode_000042_frame_000059`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 9: `episode_000027_frame_000385`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 10: `episode_000004_frame_000792`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 11: `episode_000018_frame_000716`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 12: `episode_000029_frame_000667`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=right, surface=asphalt, heading alignment=slightly right, action steer=right, skid marks visible=no, transition=entering turn
# ```
# ## Pair 13: `episode_000002_frame_000928`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 14: `episode_000046_frame_000520`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 15: `episode_000025_frame_000982`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 16: `episode_000010_frame_000986`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 17: `episode_000001_frame_000869`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 18: `episode_000004_frame_000404`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=right, surface=asphalt, heading alignment=slightly right, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 19: `episode_000022_frame_000287`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle right, car position=center, surface=asphalt, heading alignment=aligned, action steer=right, skid marks visible=no, transition=entering turn
# ```
# ## Pair 20: `episode_000021_frame_000423`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 21: `episode_000003_frame_000660`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=center, surface=asphalt, heading alignment=slightly left, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 22: `episode_000012_frame_000283`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 23: `episode_000004_frame_000523`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 24: `episode_000028_frame_000195`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 25: `episode_000021_frame_000746`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 26: `episode_000003_frame_000116`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 27: `episode_000042_frame_000256`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=center, surface=mixed, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 28: `episode_000028_frame_000858`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 29: `episode_000006_frame_000391`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 30: `episode_000011_frame_000319`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 31: `episode_000032_frame_000218`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 32: `episode_000032_frame_000137`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 33: `episode_000003_frame_000430`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 34: `episode_000029_frame_000441`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle right, car position=right, surface=mixed, heading alignment=slightly right, action steer=right, skid marks visible=no, transition=entering turn
# ```
# ## Pair 35: `episode_000029_frame_000792`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 36: `episode_000020_frame_000312`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 37: `episode_000002_frame_000369`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 38: `episode_000049_frame_000974`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle right, car position=right, surface=asphalt, heading alignment=aligned, action steer=right, skid marks visible=no, transition=entering turn
# ```
# ## Pair 39: `episode_000011_frame_000259`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=right, surface=mixed, heading alignment=slightly right, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 40: `episode_000002_frame_000210`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 41: `episode_000028_frame_000438`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle left, car position=center, surface=asphalt, heading alignment=aligned, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 42: `episode_000043_frame_000968`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=mixed, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 43: `episode_000006_frame_000775`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle right, car position=center, surface=asphalt, heading alignment=aligned, action steer=right, skid marks visible=no, transition=entering turn
# ```
# ## Pair 44: `episode_000014_frame_000885`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp right, car position=center, surface=asphalt, heading alignment=aligned, action steer=right, skid marks visible=no, transition=entering turn
# ```
# ## Pair 45: `episode_000021_frame_000436`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=center, surface=asphalt, heading alignment=slightly left, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 46: `episode_000007_frame_000466`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=sharp left, car position=right, surface=mixed, heading alignment=slightly right, action steer=left, skid marks visible=no, transition=entering turn
# ```
# ## Pair 47: `episode_000027_frame_000730`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=gentle right, car position=right, surface=asphalt, heading alignment=slightly right, action steer=right, skid marks visible=no, transition=entering turn
# ```
# ## Pair 48: `episode_000006_frame_000123`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 49: `episode_000029_frame_000249`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
# ## Pair 50: `episode_000015_frame_000713`
# <PIL.Image.Image image mode=RGB size=64x64>
# **Caption**
# ```text
# road shape=straight, car position=center, surface=asphalt, heading alignment=aligned, action steer=neutral, skid marks visible=no, transition=stable
# ```
